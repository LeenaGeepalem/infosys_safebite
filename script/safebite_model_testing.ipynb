# %% [markdown]
# ## Model Testing

# %%
import joblib
import pandas as pd
import numpy as np
import os

# %%
example_df=pd.read_csv('C:/Users/Admin/Desktop/sample.csv',na_values=[""],keep_default_na=False)

# %%
example_df.head(9)
# Out:
#             Food Product Main Ingredient      Sweetener       Fat/Oil  \
# 0  Blueberry Protein Bar     Blueberries          Honey    Almond oil
# 1     Mango Chia Pudding           Mango  Coconut sugar  Coconut milk
# 2         Beetroot Chips        Beetroot           None     Olive oil
# 3   Pumpkin Spice Muffin         Pumpkin    Maple syrup        Butter
# 4            Lentil Soup         Lentils           None     Olive oil
# 5      Quinoa Sushi Roll          Quinoa           None   Avocado oil
# 6         Turmeric Latte        Turmeric     Date syrup   Coconut oil
# 7          Seaweed Snack         Seaweed           None    Sesame oil
# 8     Hazelnut Milkshake       Hazelnuts    Agave syrup  Hazelnut oil
#
#               Seasoning     Allergens  Price ($)  Customer rating (Out of 5)
# 0       Vanilla extract     Tree nuts       2.99                         4.2
# 1              Cardamom       Coconut       4.49                         4.5
# ...

# %%
# Rename the columns
example_df.rename(columns={'Price ($)': 'Price', 'Customer rating (Out of 5)': 'Customer rating'}, inplace=True)

# %%
# Load the model and encoder from the file
encoder_path='C:/Users/Admin/Desktop/food_allergen_detection/Models/encoder.pkl'
model_path = 'C:/Users/Admin/Desktop/food_allergen_detection/Models/rf_model.pkl'

encoder=joblib.load(encoder_path)
rf_model = joblib.load(model_path)

# %%
categorical_columns = ['Food Product', 'Main Ingredient', 'Sweetener', 'Fat/Oil', 'Seasoning','Allergens']

example_df_encoded=encoder.transform(example_df[categorical_columns])

example_df=pd.concat([example_df.drop(categorical_columns,axis=1),example_df_encoded],axis=1)

# %%
example_df
# Out:
#    Price  Customer rating  Food Product  Main Ingredient  Sweetener  \
# 0   2.99              4.2     12.397588        12.397588  13.235000
# 1   4.49              4.5     12.397588         9.720000  12.397588
# 2   3.25              3.8     12.397588        12.397588  12.397599
# 3   5.75              4.7     12.397588        13.792500  12.397588
# 4   4.00              4.0     11.245000        11.790000  12.397599
# 5   6.50              4.6     12.397588        13.760000  12.397599
# 6   3.75              4.3     12.397588        12.397588  12.397588
# 7   2.50              3.9     12.397588        12.397588  12.397599
# 8   5.25              4.8     12.397588        12.397588  12.397588
# 9   6.00              4.1     12.397588        12.397588  12.397599
#
#      Fat/Oil  Seasoning  Allergens
# 0  12.397588  12.246250  12.397588
# 1  10.597778  12.397588  12.397588
# 2  13.094000  12.397588  12.165608
# 3  12.444471  12.397588  13.050563
# 4  13.094000  12.397588  12.165608
# ...

# %%
# Make predictions using the loaded model
prediction = rf_model.predict(example_df)

print(prediction)
# Out:
# [0 0 1 0 1 0 1 1 0 1]
